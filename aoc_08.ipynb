# %%
TEST = True
DEBUG = True
X = """be cfbegad cbdgef fgaecd cgeb fdcge agebfd fecdb fabcd edb | fdgacbe cefdb cefbgd gcbe
edbfga begcd cbg gc gcadebf fbgde acbgfd abcde gfcbed gfec | fcgedb cgb dgebacf gc
fgaebd cg bdaec gdafb agbcfd gdcbef bgcad gfac gcb cdgabef | cg cg fdcagb cbg
fbegcd cbd adcefb dageb afcb bc aefdc ecdab fgdeca fcdbega | efabcd cedba gadfec cb
aecbfdg fbg gf bafeg dbefa fcge gcbea fcaegb dgceab fcbdga | gecf egdcabf bgf bfgea
fgeab ca afcebg bdacfeg cfaedg gcfdb baec bfadeg bafgc acf | gebdcfa ecba ca fadegcb
dbcfg fgd bdegcaf fgec aegbdf ecdfab fbedc dacgb gdcebf gf | cefg dcbef fcge gbcadfe
bdfegc cbegaf gecbf dfcage bdacg ed bedf ced adcbefg gebcd | ed bcgafe cdgba cbgef
egadfb cdbfeg cegd fecab cgb gbdefca cg fgcdab egfdb bfceg | gbdfcae bgc cg cgb
gcafb gcf dcaebfg ecagb gf abcdeg gaef cafbge fdbac fegbdc | fgae cfgab fg bagce"""

import sys

if not TEST:
    with open("aoc_8_input.txt", "r") as f:
        X = f.read().strip()
        
data = []
for el in X.strip().split("\n"):
    inp,out = el.strip().split("|")
    a = []
    b = []
    for i in inp.strip().split(" "):
        a.append( i.strip())
    for i in out.strip().split(" "):
        b.append( i.strip())
    data.append([a,b])
           
if DEBUG:
    for index,el in enumerate(data):
        inp,out = data[index]
        for el in inp:
            sys.stdout.write( "".join(el) )
            sys.stdout.write(" ")
        sys.stdout.write( "\t" )
        for el in out:
            sys.stdout.write( "".join(el) )
            sys.stdout.write(" ")
        print()
# Out:
# be cfbegad cbdgef fgaecd cgeb fdcge agebfd fecdb fabcd edb 	fdgacbe cefdb cefbgd gcbe
# edbfga begcd cbg gc gcadebf fbgde acbgfd abcde gfcbed gfec 	fcgedb cgb dgebacf gc
# fgaebd cg bdaec gdafb agbcfd gdcbef bgcad gfac gcb cdgabef 	cg cg fdcagb cbg
# fbegcd cbd adcefb dageb afcb bc aefdc ecdab fgdeca fcdbega 	efabcd cedba gadfec cb
# aecbfdg fbg gf bafeg dbefa fcge gcbea fcaegb dgceab fcbdga 	gecf egdcabf bgf bfgea
# fgeab ca afcebg bdacfeg cfaedg gcfdb baec bfadeg bafgc acf 	gebdcfa ecba ca fadegcb
# dbcfg fgd bdegcaf fgec aegbdf ecdfab fbedc dacgb gdcebf gf 	cefg dcbef fcge gbcadfe
# bdfegc cbegaf gecbf dfcage bdacg ed bedf ced adcbefg gebcd 	ed bcgafe cdgba cbgef
# egadfb cdbfeg cegd fecab cgb gbdefca cg fgcdab egfdb bfceg 	gbdfcae bgc cg cgb
# gcafb gcf dcaebfg ecagb gf abcdeg gaef cafbge fdbac fegbdc 	fgae cfgab fg bagce

# %%
#Part1
segment = {}
for i in range(0,10):
    segment.update({i:[]})

count = 0
for index,subdata in enumerate(data):
    for el in subdata[1]:
        if len(el) == 2:
            count += 1
            if "".join(el) not in segment[1]:
                segment[1].append(el)
        elif len(el) == 3:
            count += 1
            if "".join(el) not in segment[1]:
                segment[1].append(el)
        elif len(el) == 4:
            count += 1
            if "".join(el) not in segment[1]:
                segment[1].append(el)
        elif len(el) == 7:
            count += 1
            if "".join(el) not in segment[1]:
                segment[1].append(el)
print("Tot: ", count)
# Out:
# Tot:  237

# %%
#Part2
disp = " {0}{0}{0}{0}\n{1}    {2}\n{1}    {2}\n {3}{3}{3}{3}\n{4}    {5}\n{4}    {5}\n {6}{6}{6}{6}\n"


count = 0
for index,subdata in enumerate(data):
    segment = [None,]*7
    for el in subdata[0]:
        if len(el) == 2: #1
            segment[2] = el[0]
            segment[5] = el[1]
            deduct[1].append(segment)
        elif len(el) == 3: #7
            segment[0] = el[0]
            segment[2] = el[1]
            segment[5] = el[2]
            deduct[7].append(segment)
        elif len(el) == 4: #4
            segment[1] = el[0]
            segment[2] = el[1]
            segment[3] = el[2]
            segment[5] = el[3]
            deduct[4].append(segment)
        elif len(el) == 7: #8
            segment[0] = el[0]
            segment[1] = el[1]
            segment[2] = el[2]
            segment[3] = el[3]
            segment[4] = el[4]
            segment[5] = el[5]
            segment[6] = el[6]
            deduct[8].append(segment)
            
    print("SEGMENT")
    for i in subdata[0]:
        print(i)
    print(disp.format(*segment))
    for el in subdata[1]:        
        s0 = segment[0]+segment[1]+segment[2]+segment[4]+segment[5]+segment[6]
        s1 = segment[2]+segment[5]
        s2 = segment[0]+segment[2]+segment[3]+segment[4]+segment[6]
        s3 = segment[0]+segment[2]+segment[3]+segment[5]+segment[6]
        s4 = segment[0]+segment[1]+segment[2]+segment[3]+segment[4]+segment[5]+segment[6]
        s5 = segment[0]+segment[1]+segment[2]+segment[3]+segment[4]+segment[5]+segment[6]
        s6 = segment[0]+segment[2]+segment[3]+segment[4]+segment[5]+segment[6]
        s7 = segment[0]+segment[2]+segment[5]
        s8 = segment[0]+segment[1]+segment[2]+segment[3]+segment[3]+segment[4]+segment[5]+segment[6]
        s9 = segment[0]+segment[1]+segment[2]+segment[3]+segment[4]+segment[3]+segment[5]+segment[6]  
        
        if el == s0:
            sys.stdout.write("0, ")
        elif el == s1:
            sys.stdout.write("1, ")
        elif el == s2:
            sys.stdout.write("2, ")
        elif el == s3:
            sys.stdout.write("3, ")
        elif el == s4:
            sys.stdout.write("?, ")
        elif el == s5:
            sys.stdout.write("?, ")
        elif el == s6:
            sys.stdout.write("?, ")
        elif el == s7:
            sys.stdout.write("7, ")
        elif el == s8:
            sys.stdout.write("?, ")
        elif el == s9:
            sys.stdout.write("?, ")
        else:
            sys.stdout.write(el+", ")
    print()
    print()
# Out:
# SEGMENT
# be
# cfbegad
# cbdgef
# fgaecd
# cgeb
# fdcge
# agebfd
# fecdb
# fabcd
# edb
#  eeee
# c    d
# c    d
#  eeee
# g    b
# g    b
#  dddd
#
# fdgacbe, cefdb, cefbgd, gcbe,
#
# SEGMENT
# edbfga
# begcd
# cbg
# gc
# gcadebf
# fbgde
# acbgfd
# abcde
# gfcbed
# gfec
#  gggg
# g    f
# g    f
#  eeee
# e    c
# e    c
#  ffff
#
# fcgedb, cgb, dgebacf, gc,
#
# SEGMENT
# fgaebd
# cg
# bdaec
# gdafb
# agbcfd
# gdcbef
# bgcad
# gfac
# gcb
# cdgabef
#  cccc
# d    g
# d    g
#  aaaa
# b    e
# b    e
#  ffff
#
# cg, cg, fdcagb, cbg,
#
# SEGMENT
# fbegcd
# cbd
# adcefb
# dageb
# afcb
# bc
# aefdc
# ecdab
# fgdeca
# fcdbega
#  ffff
# c    d
# c    d
#  bbbb
# e    g
# e    g
#  aaaa
#
# efabcd, cedba, gadfec, cb,
#
# SEGMENT
# aecbfdg
# fbg
# gf
# bafeg
# dbefa
# fcge
# gcbea
# fcaegb
# dgceab
# fcbdga
#  ffff
# f    c
# f    c
#  gggg
# f    e
# f    e
#  gggg
#
# gecf, egdcabf, bgf, bfgea,
#
# SEGMENT
# fgeab
# ca
# afcebg
# bdacfeg
# cfaedg
# gcfdb
# baec
# bfadeg
# bafgc
# acf
# ...
